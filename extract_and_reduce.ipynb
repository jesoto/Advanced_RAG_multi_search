# %% [markdown]
# ## Getting data from wikipedia

# %%
# !pip install langchain
# !pip install wikipedia
# Out:
# Requirement already satisfied: langchain in c:\users\jesus\anaconda3\lib\site-packages (0.1.5)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\jesus\anaconda3\lib\site-packages (from langchain) (6.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\jesus\anaconda3\lib\site-packages (from langchain) (1.4.39)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\jesus\anaconda3\lib\site-packages (from langchain) (3.8.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\jesus\anaconda3\lib\site-packages (from langchain) (0.6.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\jesus\anaconda3\lib\site-packages (from langchain) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.17 in c:\users\jesus\anaconda3\lib\site-packages (from langchain) (0.0.17)
# Requirement already satisfied: langchain-core<0.2,>=0.1.16 in c:\users\jesus\anaconda3\lib\site-packages (from langchain) (0.1.18)
# Requirement already satisfied: langsmith<0.1,>=0.0.83 in c:\users\jesus\anaconda3\lib\site-packages (from langchain) (0.0.86)
# Requirement already satisfied: numpy<2,>=1 in c:\users\jesus\anaconda3\lib\site-packages (from langchain) (1.24.3)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\jesus\anaconda3\lib\site-packages (from langchain) (1.10.8)
# Requirement already satisfied: requests<3,>=2 in c:\users\jesus\anaconda3\lib\site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\jesus\anaconda3\lib\site-packages (from langchain) (8.2.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\jesus\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (22.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\jesus\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\jesus\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\jesus\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\jesus\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\jesus\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\jesus\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.2.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\jesus\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.20.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\jesus\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\jesus\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.1)
# Requirement already satisfied: anyio<5,>=3 in c:\users\jesus\anaconda3\lib\site-packages (from langchain-core<0.2,>=0.1.16->langchain) (3.5.0)
# Requirement already satisfied: packaging<24.0,>=23.2 in c:\users\jesus\anaconda3\lib\site-packages (from langchain-core<0.2,>=0.1.16->langchain) (23.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\jesus\anaconda3\lib\site-packages (from pydantic<3,>=1->langchain) (4.7.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jesus\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jesus\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jesus\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2023.7.22)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\jesus\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (2.0.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\jesus\anaconda3\lib\site-packages (from anyio<5,>=3->langchain-core<0.2,>=0.1.16->langchain) (1.2.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\jesus\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (1.0.0)
# Collecting wikipedia
#   Downloading wikipedia-1.4.0.tar.gz (27 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: beautifulsoup4 in c:\users\jesus\anaconda3\lib\site-packages (from wikipedia) (4.12.2)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\users\jesus\anaconda3\lib\site-packages (from wikipedia) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jesus\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jesus\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jesus\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jesus\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2023.7.22)
# Requirement already satisfied: soupsieve>1.2 in c:\users\jesus\anaconda3\lib\site-packages (from beautifulsoup4->wikipedia) (2.4)
# Building wheels for collected packages: wikipedia
#   Building wheel for wikipedia (setup.py): started
#   Building wheel for wikipedia (setup.py): finished with status 'done'
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11707 sha256=a5f55c1a42866948b32ed018e157249e9f9a1791a21ec228df2e8a3aa5288f46
#   Stored in directory: c:\users\jesus\appdata\local\pip\cache\wheels\8f\ab\cb\45ccc40522d3a1c41e1d2ad53b8f33a62f394011ec38cd71c6
# Successfully built wikipedia
# Installing collected packages: wikipedia
# Successfully installed wikipedia-1.4.0

# %%
#load the Open AI wikipedia page
from langchain.document_loaders import WikipediaLoader
from langchain.text_splitter import CharacterTextSplitter
raw_documents = WikipediaLoader(query='OpenAI').load()

# %%
# define chunking strategy
text_splitter = CharacterTextSplitter.from_tiktoken_encoder(
    chunk_size = 1000, chunk_overlap = 20
)

#CHUNK the document
documents = text_splitter.split_documents(raw_documents)
for d in documents:
    del d.metadata['summary']

# %%
for doc in documents:
    print(doc.metadata['source'])
# Out:
# https://en.wikipedia.org/wiki/OpenAI
# https://en.wikipedia.org/wiki/OpenAI_Codex
# https://en.wikipedia.org/wiki/ChatGPT
# https://en.wikipedia.org/wiki/OpenAI_Five
# https://en.wikipedia.org/wiki/Removal_of_Sam_Altman_from_OpenAI
# https://en.wikipedia.org/wiki/Gemini_(chatbot)
# https://en.wikipedia.org/wiki/Generative_artificial_intelligence
# https://en.wikipedia.org/wiki/Sam_Altman
# https://en.wikipedia.org/wiki/Artificial_general_intelligence
# https://en.wikipedia.org/wiki/Whisper_(speech_recognition_system)
# https://en.wikipedia.org/wiki/Generative_pre-trained_transformer
# https://en.wikipedia.org/wiki/GPT-4
# https://en.wikipedia.org/wiki/Gemini_(language_model)
# https://en.wikipedia.org/wiki/Perplexity.ai
# https://en.wikipedia.org/wiki/Greg_Brockman
# https://en.wikipedia.org/wiki/GPT-3
# https://en.wikipedia.org/wiki/Large_language_model
# https://en.wikipedia.org/wiki/AI_boom
# https://en.wikipedia.org/wiki/Mira_Murati
# https://en.wikipedia.org/wiki/AI_alignment
# https://en.wikipedia.org/wiki/Emmett_Shear
# https://en.wikipedia.org/wiki/XAI_(company)
# https://en.wikipedia.org/wiki/Auto-GPT
# https://en.wikipedia.org/wiki/Elon_Musk
# https://en.wikipedia.org/wiki/Wojciech_Zaremba

# %% [markdown]
# ## Load news articles

# %%
from langchain.document_loaders import PyPDFLoader
from langchain.docstore.document import Document
import os

directory_path = 'news'
#Initialize PyPDFLoader for each PDF in directory
loaders = [PyPDFLoader(os.path.join(directory_path,f)) for f in os.listdir(directory_path) if f.endswith('.pdf')]


#load documents from PDF
news_docs = []
for loader in loaders:
    news_docs.extend(loader.load())
    
#prepare the content and metadata for each news article as document objects

news_articles_data = [
    Document(
        page_content=doc.page_content, 
        metadata={
            'source': doc.metadata['source'].removeprefix('news/'),
        }
    )
    for doc in news_docs
    
]

# %%
# !pip install spacy-llm
# !pip install --upgrade jupyter ipywidgets
# Out:
# Collecting spacy-llm
#   Obtaining dependency information for spacy-llm from https://files.pythonhosted.org/packages/23/dc/19b155fd5cdc4b2d2306b79043491a11f42df8e71277ac3cad1a5110b94e/spacy_llm-0.7.1-py2.py3-none-any.whl.metadata
#   Downloading spacy_llm-0.7.1-py2.py3-none-any.whl.metadata (10 kB)
# Collecting spacy<4.0,>=3.5 (from spacy-llm)
#   Obtaining dependency information for spacy<4.0,>=3.5 from https://files.pythonhosted.org/packages/92/fb/d1f0605e1e8627226c6c96053fe1632e9a04a3fbcd8b5d715528cb95eb97/spacy-3.7.4-cp311-cp311-win_amd64.whl.metadata
#   Downloading spacy-3.7.4-cp311-cp311-win_amd64.whl.metadata (27 kB)
# Requirement already satisfied: jinja2 in c:\users\jesus\anaconda3\lib\site-packages (from spacy-llm) (3.1.2)
# Collecting confection<1.0.0,>=0.1.3 (from spacy-llm)
#   Obtaining dependency information for confection<1.0.0,>=0.1.3 from https://files.pythonhosted.org/packages/39/78/f9d18da7b979a2e6007bfcea2f3c8cc02ed210538ae1ce7e69092aed7b18/confection-0.1.4-py3-none-any.whl.metadata
#   Downloading confection-0.1.4-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\jesus\anaconda3\lib\site-packages (from confection<1.0.0,>=0.1.3->spacy-llm) (1.10.8)
# Collecting srsly<3.0.0,>=2.4.0 (from confection<1.0.0,>=0.1.3->spacy-llm)
#   Obtaining dependency information for srsly<3.0.0,>=2.4.0 from https://files.pythonhosted.org/packages/eb/f5/e3f29993f673d91623df6413ba64e815dd2676fd7932cbc5e7347402ddae/srsly-2.4.8-cp311-cp311-win_amd64.whl.metadata
#   Downloading srsly-2.4.8-cp311-cp311-win_amd64.whl.metadata (20 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy<4.0,>=3.5->spacy-llm)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy<4.0,>=3.5->spacy-llm)
#   Obtaining dependency information for spacy-loggers<2.0.0,>=1.0.0 from https://files.pythonhosted.org/packages/33/78/d1a1a026ef3af911159398c939b1509d5c36fe524c7b644f34a5146c4e16/spacy_loggers-1.0.5-py3-none-any.whl.metadata
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy<4.0,>=3.5->spacy-llm)
#   Obtaining dependency information for murmurhash<1.1.0,>=0.28.0 from https://files.pythonhosted.org/packages/71/46/af01a20ec368bd9cb49a1d2df15e3eca113bbf6952cc1f2a47f1c6801a7f/murmurhash-1.0.10-cp311-cp311-win_amd64.whl.metadata
#   Downloading murmurhash-1.0.10-cp311-cp311-win_amd64.whl.metadata (2.0 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy<4.0,>=3.5->spacy-llm)
#   Obtaining dependency information for cymem<2.1.0,>=2.0.2 from https://files.pythonhosted.org/packages/c1/c3/dd044e6f62a3d317c461f6f0c153c6573ed13025752d779e514000c15dd2/cymem-2.0.8-cp311-cp311-win_amd64.whl.metadata
#   Downloading cymem-2.0.8-cp311-cp311-win_amd64.whl.metadata (8.6 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy<4.0,>=3.5->spacy-llm)
#   Obtaining dependency information for preshed<3.1.0,>=3.0.2 from https://files.pythonhosted.org/packages/e4/fc/78cdbdb79f5d6d45949e72c32445d6c060977ad50a1dcfc0392622165f7c/preshed-3.0.9-cp311-cp311-win_amd64.whl.metadata
#   Downloading preshed-3.0.9-cp311-cp311-win_amd64.whl.metadata (2.2 kB)
# Collecting thinc<8.3.0,>=8.2.2 (from spacy<4.0,>=3.5->spacy-llm)
#   Obtaining dependency information for thinc<8.3.0,>=8.2.2 from https://files.pythonhosted.org/packages/de/a5/c242d57dc7a8afe677aa48ce370d84be3d04523cbb819c4a36b64f35155c/thinc-8.2.3-cp311-cp311-win_amd64.whl.metadata
#   Downloading thinc-8.2.3-cp311-cp311-win_amd64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy<4.0,>=3.5->spacy-llm)
#   Obtaining dependency information for wasabi<1.2.0,>=0.9.1 from https://files.pythonhosted.org/packages/8f/69/26cbf0bad11703241cb84d5324d868097f7a8faf2f1888354dac8883f3fc/wasabi-1.1.2-py3-none-any.whl.metadata
#   Downloading wasabi-1.1.2-py3-none-any.whl.metadata (28 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy<4.0,>=3.5->spacy-llm)
#   Obtaining dependency information for catalogue<2.1.0,>=2.0.6 from https://files.pythonhosted.org/packages/9e/96/d32b941a501ab566a16358d68b6eb4e4acc373fab3c3c4d7d9e649f7b4bb/catalogue-2.0.10-py3-none-any.whl.metadata
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.4.0,>=0.1.0 (from spacy<4.0,>=3.5->spacy-llm)
#   Obtaining dependency information for weasel<0.4.0,>=0.1.0 from https://files.pythonhosted.org/packages/d5/e5/b63b8e255d89ba4155972990d42523251d4d1368c4906c646597f63870e2/weasel-0.3.4-py3-none-any.whl.metadata
#   Downloading weasel-0.3.4-py3-none-any.whl.metadata (4.7 kB)
# Collecting typer<0.10.0,>=0.3.0 (from spacy<4.0,>=3.5->spacy-llm)
#   Obtaining dependency information for typer<0.10.0,>=0.3.0 from https://files.pythonhosted.org/packages/bf/0e/c68adf10adda05f28a6ed7b9f4cd7b8e07f641b44af88ba72d9c89e4de7a/typer-0.9.0-py3-none-any.whl.metadata
#   Downloading typer-0.9.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\jesus\anaconda3\lib\site-packages (from spacy<4.0,>=3.5->spacy-llm) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\jesus\anaconda3\lib\site-packages (from spacy<4.0,>=3.5->spacy-llm) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\jesus\anaconda3\lib\site-packages (from spacy<4.0,>=3.5->spacy-llm) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\jesus\anaconda3\lib\site-packages (from spacy<4.0,>=3.5->spacy-llm) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\jesus\anaconda3\lib\site-packages (from spacy<4.0,>=3.5->spacy-llm) (23.2)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy<4.0,>=3.5->spacy-llm)
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      ---------------------------------------- 0.0/181.6 kB ? eta -:--:--
#      -------------------------------------- 181.6/181.6 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.19.0 in c:\users\jesus\anaconda3\lib\site-packages (from spacy<4.0,>=3.5->spacy-llm) (1.24.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jesus\anaconda3\lib\site-packages (from jinja2->spacy-llm) (2.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\jesus\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->confection<1.0.0,>=0.1.3->spacy-llm) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jesus\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0,>=3.5->spacy-llm) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jesus\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0,>=3.5->spacy-llm) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jesus\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0,>=3.5->spacy-llm) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jesus\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0,>=3.5->spacy-llm) (2023.7.22)
# Collecting blis<0.8.0,>=0.7.8 (from thinc<8.3.0,>=8.2.2->spacy<4.0,>=3.5->spacy-llm)
#   Obtaining dependency information for blis<0.8.0,>=0.7.8 from https://files.pythonhosted.org/packages/2f/09/da0592c74560cc33396504698122f7a56747c82a5e072ca7d2c3397898e1/blis-0.7.11-cp311-cp311-win_amd64.whl.metadata
#   Downloading blis-0.7.11-cp311-cp311-win_amd64.whl.metadata (7.6 kB)
# Requirement already satisfied: colorama in c:\users\jesus\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<4.0,>=3.5->spacy-llm) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\jesus\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<4.0,>=3.5->spacy-llm) (8.0.4)
# Collecting cloudpathlib<0.17.0,>=0.7.0 (from weasel<0.4.0,>=0.1.0->spacy<4.0,>=3.5->spacy-llm)
#   Obtaining dependency information for cloudpathlib<0.17.0,>=0.7.0 from https://files.pythonhosted.org/packages/0f/6e/45b57a7d4573d85d0b0a39d99673dc1f5eea9d92a1a4603b35e968fbf89a/cloudpathlib-0.16.0-py3-none-any.whl.metadata
#   Downloading cloudpathlib-0.16.0-py3-none-any.whl.metadata (14 kB)
# Downloading spacy_llm-0.7.1-py2.py3-none-any.whl (255 kB)
#    ---------------------------------------- 0.0/255.9 kB ? eta -:--:--
#    ---------------------------------------- 255.9/255.9 kB 7.9 MB/s eta 0:00:00
# Downloading confection-0.1.4-py3-none-any.whl (35 kB)
# Downloading spacy-3.7.4-cp311-cp311-win_amd64.whl (12.1 MB)
#    ---------------------------------------- 0.0/12.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/12.1 MB 7.0 MB/s eta 0:00:02
#    -- ------------------------------------- 0.7/12.1 MB 7.6 MB/s eta 0:00:02
#    --- ------------------------------------ 1.1/12.1 MB 7.5 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.4/12.1 MB 7.5 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.6/12.1 MB 7.6 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.7/12.1 MB 5.8 MB/s eta 0:00:02
#    ------ --------------------------------- 1.9/12.1 MB 6.1 MB/s eta 0:00:02
#    ------ --------------------------------- 2.1/12.1 MB 6.0 MB/s eta 0:00:02
#    -------- ------------------------------- 2.4/12.1 MB 6.0 MB/s eta 0:00:02
#    --------- ------------------------------ 2.8/12.1 MB 6.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.3/12.1 MB 6.5 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.6/12.1 MB 6.6 MB/s eta 0:00:02
#    ------------- -------------------------- 4.0/12.1 MB 6.7 MB/s eta 0:00:02
#    ------------- -------------------------- 4.2/12.1 MB 6.8 MB/s eta 0:00:02
#    ------------- -------------------------- 4.2/12.1 MB 6.8 MB/s eta 0:00:02
#    ------------- -------------------------- 4.2/12.1 MB 5.7 MB/s eta 0:00:02
#    -------------- ------------------------- 4.3/12.1 MB 5.8 MB/s eta 0:00:02
#    -------------- ------------------------- 4.3/12.1 MB 5.8 MB/s eta 0:00:02
#    --------------- ------------------------ 4.5/12.1 MB 5.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.9/12.1 MB 5.3 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.2/12.1 MB 5.3 MB/s eta 0:00:02
#    ------------------ --------------------- 5.6/12.1 MB 5.5 MB/s eta 0:00:02
#    ------------------- -------------------- 5.9/12.1 MB 5.6 MB/s eta 0:00:02
#    -------------------- ------------------- 6.3/12.1 MB 5.7 MB/s eta 0:00:02
#    --------------------- ------------------ 6.5/12.1 MB 5.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.9/12.1 MB 5.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.0/12.1 MB 5.7 MB/s eta 0:00:01
#    ------------------------ --------------- 7.3/12.1 MB 5.7 MB/s eta 0:00:01
#    ------------------------- -------------- 7.6/12.1 MB 5.7 MB/s eta 0:00:01
#    -------------------------- ------------- 8.0/12.1 MB 5.8 MB/s eta 0:00:01
#    -------------------------- ------------- 8.1/12.1 MB 5.7 MB/s eta 0:00:01
#    --------------------------- ------------ 8.4/12.1 MB 5.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.9/12.1 MB 5.8 MB/s eta 0:00:01
#    ------------------------------ --------- 9.2/12.1 MB 5.9 MB/s eta 0:00:01
#    ------------------------------- -------- 9.7/12.1 MB 6.0 MB/s eta 0:00:01
#    --------------------------------- ------ 10.0/12.1 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.4/12.1 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.5/12.1 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.5/12.1 MB 6.0 MB/s eta 0:00:01
#    ------------------------------------ --- 10.9/12.1 MB 5.7 MB/s eta 0:00:01
#    ------------------------------------- -- 11.2/12.1 MB 5.8 MB/s eta 0:00:01
#    -------------------------------------- - 11.6/12.1 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------  11.8/12.1 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------  11.9/12.1 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------  12.1/12.1 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------- 12.1/12.1 MB 5.7 MB/s eta 0:00:00
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cymem-2.0.8-cp311-cp311-win_amd64.whl (39 kB)
# Downloading murmurhash-1.0.10-cp311-cp311-win_amd64.whl (25 kB)
# Downloading preshed-3.0.9-cp311-cp311-win_amd64.whl (122 kB)
#    ---------------------------------------- 0.0/122.3 kB ? eta -:--:--
#    ---------------------------------------- 122.3/122.3 kB 3.6 MB/s eta 0:00:00
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.4.8-cp311-cp311-win_amd64.whl (479 kB)
#    ---------------------------------------- 0.0/479.7 kB ? eta -:--:--
#    --------------------- ------------------ 256.0/479.7 kB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 479.7/479.7 kB 5.9 MB/s eta 0:00:00
# Downloading thinc-8.2.3-cp311-cp311-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    -------- ------------------------------- 0.3/1.5 MB 6.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.7/1.5 MB 6.9 MB/s eta 0:00:01
#    -------------------------- ------------- 1.0/1.5 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.3/1.5 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.3/1.5 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 5.2 MB/s eta 0:00:00
# Downloading typer-0.9.0-py3-none-any.whl (45 kB)
#    ---------------------------------------- 0.0/45.9 kB ? eta -:--:--
#    ---------------------------------------- 45.9/45.9 kB ? eta 0:00:00
# Downloading wasabi-1.1.2-py3-none-any.whl (27 kB)
# Downloading weasel-0.3.4-py3-none-any.whl (50 kB)
#    ---------------------------------------- 0.0/50.1 kB ? eta -:--:--
#    ---------------------------------------- 50.1/50.1 kB ? eta 0:00:00
# Downloading blis-0.7.11-cp311-cp311-win_amd64.whl (6.6 MB)
#    ---------------------------------------- 0.0/6.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.4/6.6 MB 8.5 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.7/6.6 MB 7.8 MB/s eta 0:00:01
#    ------ --------------------------------- 1.0/6.6 MB 8.3 MB/s eta 0:00:01
#    ------ --------------------------------- 1.0/6.6 MB 8.3 MB/s eta 0:00:01
#    ------ --------------------------------- 1.1/6.6 MB 4.6 MB/s eta 0:00:02
#    -------- ------------------------------- 1.4/6.6 MB 5.1 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.7/6.6 MB 5.5 MB/s eta 0:00:01
#    ------------ --------------------------- 2.1/6.6 MB 5.9 MB/s eta 0:00:01
#    ------------- -------------------------- 2.3/6.6 MB 5.9 MB/s eta 0:00:01
#    -------------- ------------------------- 2.4/6.6 MB 5.3 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.7/6.6 MB 5.4 MB/s eta 0:00:01
#    ------------------ --------------------- 3.1/6.6 MB 5.6 MB/s eta 0:00:01
#    ------------------- -------------------- 3.1/6.6 MB 5.6 MB/s eta 0:00:01
#    ------------------- -------------------- 3.3/6.6 MB 5.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.6/6.6 MB 5.3 MB/s eta 0:00:01
#    ------------------------ --------------- 4.1/6.6 MB 5.5 MB/s eta 0:00:01
#    -------------------------- ------------- 4.4/6.6 MB 5.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 4.8/6.6 MB 5.8 MB/s eta 0:00:01
#    ------------------------------- -------- 5.2/6.6 MB 5.9 MB/s eta 0:00:01
#    ------------------------------- -------- 5.2/6.6 MB 5.9 MB/s eta 0:00:01
#    ------------------------------- -------- 5.2/6.6 MB 5.9 MB/s eta 0:00:01
#    ------------------------------- -------- 5.2/6.6 MB 5.9 MB/s eta 0:00:01
#    ------------------------------- -------- 5.2/6.6 MB 5.9 MB/s eta 0:00:01
#    --------------------------------- ------ 5.4/6.6 MB 4.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 5.8/6.6 MB 5.0 MB/s eta 0:00:01
#    ------------------------------------ --- 6.1/6.6 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------  6.6/6.6 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 6.6/6.6 MB 5.1 MB/s eta 0:00:00
# Downloading cloudpathlib-0.16.0-py3-none-any.whl (45 kB)
#    ---------------------------------------- 0.0/45.0 kB ? eta -:--:--
#    ---------------------------------------- 45.0/45.0 kB ? eta 0:00:00
# Installing collected packages: cymem, wasabi, spacy-loggers, spacy-legacy, murmurhash, langcodes, cloudpathlib, catalogue, blis, typer, srsly, preshed, confection, weasel, thinc, spacy, spacy-llm
# Successfully installed blis-0.7.11 catalogue-2.0.10 cloudpathlib-0.16.0 confection-0.1.4 cymem-2.0.8 langcodes-3.3.0 murmurhash-1.0.10 preshed-3.0.9 spacy-3.7.4 spacy-legacy-3.0.12 spacy-llm-0.7.1 spacy-loggers-1.0.5 srsly-2.4.8 thinc-8.2.3 typer-0.9.0 wasabi-1.1.2 weasel-0.3.4
# Requirement already satisfied: jupyter in c:\users\jesus\anaconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: ipywidgets in c:\users\jesus\anaconda3\lib\site-packages (8.0.4)
# Collecting ipywidgets
#   Obtaining dependency information for ipywidgets from https://files.pythonhosted.org/packages/70/1a/7edeedb1c089d63ccd8bd5c0612334774e90cf9337de9fe6c82d90081791/ipywidgets-8.1.2-py3-none-any.whl.metadata
#   Downloading ipywidgets-8.1.2-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: notebook in c:\users\jesus\anaconda3\lib\site-packages (from jupyter) (6.5.4)
# Requirement already satisfied: qtconsole in c:\users\jesus\anaconda3\lib\site-packages (from jupyter) (5.4.2)
# Requirement already satisfied: jupyter-console in c:\users\jesus\anaconda3\lib\site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\jesus\anaconda3\lib\site-packages (from jupyter) (6.5.4)
# Requirement already satisfied: ipykernel in c:\users\jesus\anaconda3\lib\site-packages (from jupyter) (6.25.0)
# Collecting comm>=0.1.3 (from ipywidgets)
#   Obtaining dependency information for comm>=0.1.3 from https://files.pythonhosted.org/packages/6e/c1/e7335bd49aa3fa3bd453e34a4580b0076804f219897ad76d4d5aa4d8f22f/comm-0.2.1-py3-none-any.whl.metadata
#   Downloading comm-0.2.1-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\jesus\anaconda3\lib\site-packages (from ipywidgets) (8.15.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\jesus\anaconda3\lib\site-packages (from ipywidgets) (5.7.1)
# Collecting widgetsnbextension~=4.0.10 (from ipywidgets)
#   Obtaining dependency information for widgetsnbextension~=4.0.10 from https://files.pythonhosted.org/packages/99/bc/82a8c3985209ca7c0a61b383c80e015fd92e74f8ba0ec1af98f9d6ca8dce/widgetsnbextension-4.0.10-py3-none-any.whl.metadata
#   Downloading widgetsnbextension-4.0.10-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.10 (from ipywidgets)
#   Obtaining dependency information for jupyterlab-widgets~=3.0.10 from https://files.pythonhosted.org/packages/24/da/db1cb0387a7e4086780aff137987ee924e953d7f91b2a870f994b9b1eeb8/jupyterlab_widgets-3.0.10-py3-none-any.whl.metadata
#   Downloading jupyterlab_widgets-3.0.10-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: backcall in c:\users\jesus\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in c:\users\jesus\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\jesus\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\jesus\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\jesus\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\jesus\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\jesus\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\jesus\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: colorama in c:\users\jesus\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\jesus\anaconda3\lib\site-packages (from ipykernel->jupyter) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\jesus\anaconda3\lib\site-packages (from ipykernel->jupyter) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\jesus\anaconda3\lib\site-packages (from ipykernel->jupyter) (5.3.0)
# Requirement already satisfied: nest-asyncio in c:\users\jesus\anaconda3\lib\site-packages (from ipykernel->jupyter) (1.5.6)
# Requirement already satisfied: packaging in c:\users\jesus\anaconda3\lib\site-packages (from ipykernel->jupyter) (23.2)
# Requirement already satisfied: psutil in c:\users\jesus\anaconda3\lib\site-packages (from ipykernel->jupyter) (5.9.0)
# Requirement already satisfied: pyzmq>=20 in c:\users\jesus\anaconda3\lib\site-packages (from ipykernel->jupyter) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\jesus\anaconda3\lib\site-packages (from ipykernel->jupyter) (6.3.2)
# Requirement already satisfied: lxml in c:\users\jesus\anaconda3\lib\site-packages (from nbconvert->jupyter) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\jesus\anaconda3\lib\site-packages (from nbconvert->jupyter) (4.12.2)
# Requirement already satisfied: bleach in c:\users\jesus\anaconda3\lib\site-packages (from nbconvert->jupyter) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\jesus\anaconda3\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\jesus\anaconda3\lib\site-packages (from nbconvert->jupyter) (0.4)
# Requirement already satisfied: jinja2>=3.0 in c:\users\jesus\anaconda3\lib\site-packages (from nbconvert->jupyter) (3.1.2)
# Requirement already satisfied: jupyterlab-pygments in c:\users\jesus\anaconda3\lib\site-packages (from nbconvert->jupyter) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jesus\anaconda3\lib\site-packages (from nbconvert->jupyter) (2.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\jesus\anaconda3\lib\site-packages (from nbconvert->jupyter) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\jesus\anaconda3\lib\site-packages (from nbconvert->jupyter) (0.5.13)
# Requirement already satisfied: nbformat>=5.1 in c:\users\jesus\anaconda3\lib\site-packages (from nbconvert->jupyter) (5.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\jesus\anaconda3\lib\site-packages (from nbconvert->jupyter) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\jesus\anaconda3\lib\site-packages (from nbconvert->jupyter) (1.2.1)
# Requirement already satisfied: argon2-cffi in c:\users\jesus\anaconda3\lib\site-packages (from notebook->jupyter) (21.3.0)
# Requirement already satisfied: ipython-genutils in c:\users\jesus\anaconda3\lib\site-packages (from notebook->jupyter) (0.2.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\jesus\anaconda3\lib\site-packages (from notebook->jupyter) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\jesus\anaconda3\lib\site-packages (from notebook->jupyter) (0.17.1)
# Requirement already satisfied: prometheus-client in c:\users\jesus\anaconda3\lib\site-packages (from notebook->jupyter) (0.14.1)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\jesus\anaconda3\lib\site-packages (from notebook->jupyter) (0.5.5)
# Requirement already satisfied: qtpy>=2.0.1 in c:\users\jesus\anaconda3\lib\site-packages (from qtconsole->jupyter) (2.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\jesus\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jesus\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\jesus\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\jesus\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (305.1)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\jesus\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook->jupyter) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\jesus\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook->jupyter) (0.2.2)
# Requirement already satisfied: fastjsonschema in c:\users\jesus\anaconda3\lib\site-packages (from nbformat>=5.1->nbconvert->jupyter) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\jesus\anaconda3\lib\site-packages (from nbformat>=5.1->nbconvert->jupyter) (4.17.3)
# Requirement already satisfied: wcwidth in c:\users\jesus\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\jesus\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook->jupyter) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\jesus\anaconda3\lib\site-packages (from argon2-cffi->notebook->jupyter) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\jesus\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.4)
# Requirement already satisfied: six>=1.9.0 in c:\users\jesus\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\jesus\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: executing in c:\users\jesus\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\jesus\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\jesus\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\jesus\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\jesus\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter) (0.18.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\jesus\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter) (3.5.0)
# Requirement already satisfied: websocket-client in c:\users\jesus\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\jesus\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter) (1.15.1)
# Requirement already satisfied: idna>=2.8 in c:\users\jesus\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\jesus\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\jesus\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter) (2.21)
# Downloading ipywidgets-8.1.2-py3-none-any.whl (139 kB)
#    ---------------------------------------- 0.0/139.4 kB ? eta -:--:--
#    ----------------------- ---------------- 81.9/139.4 kB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 139.4/139.4 kB 2.7 MB/s eta 0:00:00
# Downloading comm-0.2.1-py3-none-any.whl (7.2 kB)
# Downloading jupyterlab_widgets-3.0.10-py3-none-any.whl (215 kB)
#    ---------------------------------------- 0.0/215.0 kB ? eta -:--:--
#    ---------------------------------------- 215.0/215.0 kB 6.4 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.10-py3-none-any.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.3 MB 9.9 MB/s eta 0:00:01
#    ------------- -------------------------- 0.8/2.3 MB 10.0 MB/s eta 0:00:01
#    ------------------ --------------------- 1.1/2.3 MB 8.5 MB/s eta 0:00:01
#    ------------------------- -------------- 1.5/2.3 MB 8.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.6/2.3 MB 8.6 MB/s eta 0:00:01
#    ------------------------------- -------- 1.8/2.3 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  2.3/2.3 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 6.6 MB/s eta 0:00:00
# Installing collected packages: widgetsnbextension, jupyterlab-widgets, comm, ipywidgets
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 4.0.5
#     Uninstalling widgetsnbextension-4.0.5:
#       Successfully uninstalled widgetsnbextension-4.0.5
#   Attempting uninstall: jupyterlab-widgets
#     Found existing installation: jupyterlab-widgets 3.0.5
#     Uninstalling jupyterlab-widgets-3.0.5:
#       Successfully uninstalled jupyterlab-widgets-3.0.5
#   Attempting uninstall: comm
#     Found existing installation: comm 0.1.2
#     Uninstalling comm-0.1.2:
#       Successfully uninstalled comm-0.1.2
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 8.0.4
#     Uninstalling ipywidgets-8.0.4:
#       Successfully uninstalled ipywidgets-8.0.4
# Successfully installed comm-0.2.1 ipywidgets-8.1.2 jupyterlab-widgets-3.0.10 widgetsnbextension-4.0.10

# %%
all_data = documents + news_articles_data

# %% [markdown]
# ## Perform Articles Summaries as relationship extraction Database

# %%
from langchain.chains.combine_documents.stuff  import StuffDocumentsChain
from langchain.chains.llm import LLMChain
from langchain.chains import MapReduceDocumentsChain, ReduceDocumentsChain
from langchain.prompts import PromptTemplate
from langchain.llms import OpenAI
from langchain.chat_models import ChatOpenAI
from langchain.text_splitter import RecursiveCharacterTextSplitter
from dotenv import load_dotenv
load_dotenv()


#Initialize the text splitter
rtext_splitter = RecursiveCharacterTextSplitter(chunk_size = 1500, chunk_overlap = 150)

# Initialize LLM
llm = ChatOpenAI(temperature = 0, model_name = 'gpt-4')

map_template = """ the following is a set of documents
{all_data}
based on this list of docs, please perform concise summaries while extracting essential relationships for relationships analysis later, 
please do include dates of actions or events, which are bery important for timeline analysis later. Example : 'Sam gets fired by the OpenAI board on 
11/17/2023 or (Nov. 17th, friday)', which showcase not only the relationships between Sam and OpenAI , but also when it happens.
Helpful answer: """
map_promp = PromptTemplate.from_template(map_template)

map_chain = LLMChain(llm=llm,prompt=map_promp)

all_data = news_articles_data + documents

# REDUCE

reduce_template = """ the following is a set of summaries:
{all_data}
Take these and distill it into concise summaries of the articles while containing important relationships and events (including the timeline).
Example: 'Sam gets fired byt the  OpenAI board on 11/17/2023 or (Nov. 17th, friday)', which showcase not only the relationships between Sam and OpenAI, but also when it happens.
Helpful Answer:"""

reduce_promp = PromptTemplate.from_template(reduce_template)

#Run chain
reduce_chain = LLMChain(llm=llm, prompt=reduce_promp)

combine_documents_chain = StuffDocumentsChain(
    llm_chain=reduce_chain,
    document_variable_name='all_data'
)

# Combines and iteravely reduces the mapped documents
reduce_documents_chain = ReduceDocumentsChain(
    #this is final chain that is calles
    combine_documents_chain=combine_documents_chain,
    #if documents exceed context for 'stuffdocumentschain'
    collapse_documents_chain=combine_documents_chain,
    #maximum numver of tokers to group documents into
    token_max=4000
)

#Combining documents by mapping a chain over them, them combining results
map_reduce_chain = MapReduceDocumentsChain(
    #map chain
    llm_chain=map_chain,
    #reduce chain
    reduce_documents_chain=reduce_documents_chain,
    #the variable name in the llm_chain to put the documents in
    document_variable_name='all_data',
    #return the results of the map steps in the output
    return_intermediate_steps=False
)

text_splitter = CharacterTextSplitter.from_tiktoken_encoder(
    chunk_size = 1000, chunk_overlap = 0
)

split_docs = text_splitter.split_documents(all_data)

# Run the MapReduce Chain
summarization_results = map_reduce_chain.run(split_docs)
# Out:
# c:\Users\jesus\anaconda3\Lib\site-packages\langchain_core\_api\deprecation.py:117: LangChainDeprecationWarning: The function `run` was deprecated in LangChain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(

# %%
summarization_results
# Out:
# "1. On February 17, 2024, Rod Stewart sold his musical rights for an undisclosed amount. \n\n2. Elon Musk reignited his dispute with OpenAI CEO, Sam Altman, on February 16, 2024, over OpenAI's decision to abandon its non-profit model.\n\n3. OpenAI introduced Sora, an AI generative model, on February 17, 2024, acknowledging that the model still faces significant challenges.\n\n4. In August 2024, wildfires in Maui led to Jeff Bezos and his fiancée Lauren Sánchez launching a $100 million fund to help the victims.\n\n5. Jeff Bezos owns a house in Maui and lent his helicopter to the Maui Fire Department for worker transportation in August 2024.\n\n6. Elon Musk launched an independent AI company, xAI, in November 2024, with its first product being an AI chatbot named Grok.\n\n7. As of an unspecified date, Forbes valued Elon Musk at $205.5 billion, making him the second richest person in the world.\n\n8. OpenAI introduced Sora, an AI capable of creating hyper-realistic videos, on February 16, 2024, and user Carolina Borges was pranked with a Rick Roll video.\n\n9. On February 17, 2024, El Confidencial published an article about Sora, OpenAI's latest AI.\n\n10. On February 24, 2017, Sam Altman, CEO of OpenAI, discussed investing seven trillion dollars in AI chips.\n\n11. Sam Altman returned as the CEO of OpenAI on November 22, 2023, after being fired by the board a few days earlier.\n\n12. Sam Altman discussed investing seven trillion dollars in chips on February 17, 2024, potentially threatening NVIDIA's privileged position in the industry.\n\n13. Sam Altman and Greg Brockman were removed from their positions at OpenAI on November 17, 2023, but returned four days later.\n\n14. OpenAI was founded in December 2015 by a group of individuals including Sam Altman and Elon Musk.\n\n15. OpenAI Codex, an AI model that generates code, powers GitHub Copilot and was trained on 159 gigabytes of Python code from 54 million GitHub repositories.\n\n16. OpenAI's chatbot, ChatGPT, launched on November 30, 2022, and had over 100 million users by January 2023.\n\n17. OpenAI Five, a computer program developed by OpenAI, first appeared publicly in 2017, defeating professional player Dendi in a one-on-one Dota 2 game.\n\n18. OpenAI, founded in December 2015, was valued at US$80 billion as of October 2023. Sam Altman took over the company following Elon Musk's resignation in 2018.\n\n19. Google developed a generative AI chatbot, initially named Bard and later renamed Gemini, in response to OpenAI's ChatGPT.\n\n20. Generative AI (GenAI or GAI) is a type of artificial intelligence that can generate text, images, or other data using generative models.\n\n21. Samuel Harris Altman, born on April 22, 1985, co-founded Loopt in 2005 and joined Y Combinator in 2011. He has been the CEO of OpenAI since 2019.\n\n22. AGI, also known as strong AI, full AI, human-level AI, or general intelligent action, is a hypothetical intelligent agent that could perform any intellectual task that humans or animals can do.\n\n23. Whisper, a machine learning model for speech recognition and transcription, was created by OpenAI and first released as open-source software in September 2022.\n\n24. Generative pre-trained transformers (GPTs) are large language models (LLMs) used in natural language processing tasks.\n\n25. OpenAI launched the Generative Pre-trained Transformer 4 (GPT-4) on March 14, 2023.\n\n26. Google DeepMind developed a family of multimodal large language models called Gemini, which powers Google's AI chatbot, also named Gemini.\n\n27. Perplexity AI, a conversational search engine, was launched in 2022. It uses the Perplexity model based on OpenAI's GPT-3.5 model and the company's standalone Large language model (LLM).\n\n28. Greg Brockman, a co-founder and president of OpenAI, left Stripe in 2015 to co-found OpenAI.\n\n29. OpenAI released the Generative Pre-trained Transformer 3 (GPT-3) in 2020.\n\n30. Large Language Models (LLMs) are artificial neural networks capable ...

# %%
#store summarization results to a text file for future use
with open('summary.txt','w') as file:
    file.write(str(summarization_results))

# %% [markdown]
# ## Spacy

# %%
#!pip install spacy-llm
# Out:
# Requirement already satisfied: spacy-llm in c:\users\jesus\anaconda3\lib\site-packages (0.7.1)
# Requirement already satisfied: spacy<4.0,>=3.5 in c:\users\jesus\anaconda3\lib\site-packages (from spacy-llm) (3.7.4)
# Requirement already satisfied: jinja2 in c:\users\jesus\anaconda3\lib\site-packages (from spacy-llm) (3.1.2)
# Requirement already satisfied: confection<1.0.0,>=0.1.3 in c:\users\jesus\anaconda3\lib\site-packages (from spacy-llm) (0.1.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\jesus\anaconda3\lib\site-packages (from confection<1.0.0,>=0.1.3->spacy-llm) (1.10.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in c:\users\jesus\anaconda3\lib\site-packages (from confection<1.0.0,>=0.1.3->spacy-llm) (2.4.8)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\jesus\anaconda3\lib\site-packages (from spacy<4.0,>=3.5->spacy-llm) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\jesus\anaconda3\lib\site-packages (from spacy<4.0,>=3.5->spacy-llm) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\jesus\anaconda3\lib\site-packages (from spacy<4.0,>=3.5->spacy-llm) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\jesus\anaconda3\lib\site-packages (from spacy<4.0,>=3.5->spacy-llm) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\jesus\anaconda3\lib\site-packages (from spacy<4.0,>=3.5->spacy-llm) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\jesus\anaconda3\lib\site-packages (from spacy<4.0,>=3.5->spacy-llm) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\jesus\anaconda3\lib\site-packages (from spacy<4.0,>=3.5->spacy-llm) (1.1.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\jesus\anaconda3\lib\site-packages (from spacy<4.0,>=3.5->spacy-llm) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\jesus\anaconda3\lib\site-packages (from spacy<4.0,>=3.5->spacy-llm) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\jesus\anaconda3\lib\site-packages (from spacy<4.0,>=3.5->spacy-llm) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\jesus\anaconda3\lib\site-packages (from spacy<4.0,>=3.5->spacy-llm) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\jesus\anaconda3\lib\site-packages (from spacy<4.0,>=3.5->spacy-llm) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\jesus\anaconda3\lib\site-packages (from spacy<4.0,>=3.5->spacy-llm) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\jesus\anaconda3\lib\site-packages (from spacy<4.0,>=3.5->spacy-llm) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\jesus\anaconda3\lib\site-packages (from spacy<4.0,>=3.5->spacy-llm) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\jesus\anaconda3\lib\site-packages (from spacy<4.0,>=3.5->spacy-llm) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\jesus\anaconda3\lib\site-packages (from spacy<4.0,>=3.5->spacy-llm) (1.24.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jesus\anaconda3\lib\site-packages (from jinja2->spacy-llm) (2.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\jesus\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->confection<1.0.0,>=0.1.3->spacy-llm) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jesus\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0,>=3.5->spacy-llm) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jesus\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0,>=3.5->spacy-llm) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jesus\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0,>=3.5->spacy-llm) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jesus\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0,>=3.5->spacy-llm) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\jesus\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<4.0,>=3.5->spacy-llm) (0.7.11)
# Requirement already satisfied: colorama in c:\users\jesus\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<4.0,>=3.5->spacy-llm) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\jesus\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<4.0,>=3.5->spacy-llm) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\jesus\anaconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<4.0,>=3.5->spacy-llm) (0.16.0)

# %%
import os 
import json
import spacy
from collections import Counter
from pathlib import Path
from wasabi import msg
from spacy_llm.util import assemble

# %%
# traditional spacy NER (Named Recognition Library)
def split_document_sent(text):
    nlp = spacy.load('en_core_web_sm')
    doc = nlp(text)
    return [sent.text.strip() for sent in doc.sents]

#spacy-llm relationship extraction
def process_text(nlp, text, verbose = False):
    doc = nlp(text)
    if verbose:
        msg.text(f'Text:{doc.text}')
        msg.text(f'Entities: {[(ent.text, ent.label_) for ent in doc.ents]}')
        msg.text('Relations')
        for r in doc._.rel:
            msg.text(f' - {doc.ents[r.dep]} [{r.relation}] {doc.ents[r.dest]}')
    return doc

def run_pipeline(config_path, examples_path = None , verbose = False):
    if not os.getenv('OPENAI_API_KEY'):
        msg.fail("OPENAI_API_KEY env variable was not found. Set it and try again", exist = 1)
